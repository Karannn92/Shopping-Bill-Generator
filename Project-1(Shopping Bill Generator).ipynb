# %%
# Simple Shopping Bill Generator

# Input details
product_name = input("Enter product name: ")
price = float(input("Enter price of product: "))
quantity = int(input("Enter quantity: "))

total = price * quantity

gst = total * 0.18
final_amt = total + gst

#(10% discount if total > 1000)
discount = False
if total > 1000:
    discount = True
    discount_amt = final_amt * 0.10
    final_amt = final_amt - discount_amt
else:
    discount_amt = 0

# Display bill
print("\n========== SHOPPING BILL ==========")
print("Product Name      :", product_name)
print("Price per item    :", price)
print("Quantity          :", quantity)
print("Total Amount      :", total)
print("GST (18%)         :", gst)
print("Discount Applied  :", discount)
print("Discount Amount   :", discount_amt)
print("Final Bill Amount :", final_amt)
print("==================================")
# Out:
# Enter product name:  Watch
# Enter price of product:  7000
# Enter quantity:  4
# ========== SHOPPING BILL ==========
# Product Name      : Watch
# Price per item    : 7000.0
# Quantity          : 4
# Total Amount      : 28000.0
# GST (18%)         : 5040.0
# Discount Applied  : True
# Discount Amount   : 3304.0
# Final Bill Amount : 29736.0
# ==================================
